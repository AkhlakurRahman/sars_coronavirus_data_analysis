# %%
! pip install chembl_webresource_client

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Querying target search

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %% [markdown]
# ## Select and retrieve Bioactivity data for SARS coronavirus 3c like proteinase

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Bioactivity data for Coronavirus 3c like proteinase that are reported as IC50 value

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')

df = pd.DataFrame.from_dict(res)
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# Creating a CSV file with the data above

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# If **standard_value** is missing from any compound, drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# ## Data preprocessing of bioactivity data

# %% [markdown]
# #### Labeling compound as either being active, inactive or intermediate

# %%
bioactivity_class = []
for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append('inactive')
    elif float(i) <= 1000:
        bioactivity_class.append('active')
    else:
        bioactivity_class.append('intermediate')

bioactivity_class
# Out:
# ['intermediate',
#  'intermediate',
#  'inactive',
#  'inactive',
#  'intermediate',
#  'active',
#  'intermediate',
#  'active',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'active',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'intermediate',
#  'inactive',
#  'intermediate',
#  'intermediate',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
#  'inactive',
# ...

# %% [markdown]
# ## **Extracting *molecule_chembl_id* to a list**

# %%
molecule_chembl_id = []
for i in df2.molecule_chembl_id:
    molecule_chembl_id.append(i)

# %% [markdown]
# ## **Extracting *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
    canonical_smiles.append(i)

# %% [markdown]
# ## **Extracting *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
    standard_value.append(i)

# %% [markdown]
# ## Combine 4 llists into a data frame

# %%
data_tuple = list(zip(molecule_chembl_id, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame(data_tuple, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class standard_value
# 0        intermediate         7200.0
# ...

# %% [markdown]
# ## Alternative (Efficient) method

# %%
selected_columns = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selected_columns]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value
# 0           7200.0
# 1           9400.0
# ...

# %%
df3 = pd.concat([df3,pd.Series(bioactivity_class)], axis=1)

# %% [markdown]
# ## Save dataframe to CSV

# %%
df3.to_csv('bioactivity_processed_data.csv', index=False)
